# %% [markdown]
# <a href="https://colab.research.google.com/github/rawalnidhi/ai-job-market-analysis-2025-2026/blob/main/notebooks/High_Demand_High_Paying_AI_Careers_2025_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # High-Demand, High-Paying AI Careers: An Analysis of the AI Job Market (2025–2026)
#
# **Course:** MSDS 670 - Data Visualization
#
# **Student:** Nidhi Rawal
#
# **University:** Regis University
#
# **Project Type:** Final Data Visualization Portfolio Project
#
# **Tools Used:** Python, Pandas, Matplotlib
#
# **Dataset:** AI Jobs Market 2025–2026 (Kaggle)
#
# ---

# %% [markdown]
# # Project Overview
#
# Artificial Intelligence continues to reshape industries and create new career opportunities across the global workforce. As organizations increase investments in AI technologies, demand for specialized professionals such as LLM Engineers, AI Agent Developers, Machine Learning Engineers, and AI Architects continues to grow.
#
# This project analyzes the AI Jobs Market 2025–2026 dataset to identify salary trends, demand patterns, and emerging career opportunities within the AI industry. The analysis focuses on understanding which AI roles offer the strongest combination of compensation and market demand.
#
# The findings are intended to help students, professionals, hiring managers, and organizations better understand the evolving AI employment landscape and identify promising career pathways.

# %% [markdown]
# # Purpose of the Study
#
# The purpose of this project is to explore the current AI job market and identify trends that influence career opportunities within the field of Artificial Intelligence.
#
# Specifically, this analysis seeks to:
#
# - Examine how salaries change across experience levels.
# - Identify the highest-paying AI roles.
# - Explore the relationship between salary and market demand.
# - Highlight emerging AI positions that offer strong career potential.
# - Provide actionable insights for individuals pursuing careers in AI.

# %% [markdown]
# # Research Question
#
# Which AI career paths offer the strongest combination of salary and market demand in the 2025–2026 job market?

# %% [markdown]
# # Dataset Description
#
# The dataset contains 1,500 AI-related job postings collected from multiple countries and industries during 2025–2026.
#
# The dataset includes information such as:
#
# - Job title
# - Job category
# - Experience level
# - Annual salary
# - Salary ranges
# - Company size
# - Industry
# - Demand score
# - Demand growth rate
# - Remote work availability
# - AI salary premium
# - Location information
#
# The dataset provides a comprehensive view of emerging AI career opportunities and compensation trends across the global market.

# %% [markdown]
# # Methodology
#
# The analysis follows a structured exploratory data analysis (EDA) approach.
#
# Steps performed include:
#
# 1. Data loading and inspection.
# 2. Data quality validation and missing value analysis.
# 3. Descriptive statistical analysis.
# 4. Aggregation of salary and demand metrics.
# 5. Development of three primary visualizations:
#    - Line Chart: Average Salary by Experience Level
#    - Horizontal Bar Chart: Top 10 Highest-Paying AI Roles
#    - Scatter Plot: Demand Score vs Average Salary by Job Role
# 6. Interpretation of findings and business recommendations.
#
# All visualizations are created using Python and Matplotlib following professional data visualization practices.

# %%
# !pip install -q adjustText

# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from adjustText import adjust_text
from matplotlib.ticker import FuncFormatter
import matplotlib.patches as mpatches


# Display settings

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
# Load dataset

df = pd.read_csv("ai_jobs_market_2025_2026.csv")

# Preview first five rows

df.head()
# Out:
#       job_id           job_title      job_category  experience_level  \
# 0  AIJOB0001  AI Agent Developer    AI Engineering  Senior (6-9 yrs)
# 1  AIJOB0002     Prompt Engineer    AI Engineering  Senior (6-9 yrs)
# 2  AIJOB0003        LLM Engineer    AI Engineering  Senior (6-9 yrs)
# 3  AIJOB0004  Data Engineer (AI)  Data Engineering  Senior (6-9 yrs)
# 4  AIJOB0005  AI Product Manager           Product    Lead (10+ yrs)
#
#    years_of_experience    education_required  annual_salary_usd  \
# 0                    7              Master's           239000.0
# 1                    2            Bachelor's           166000.0
# 2                    4           Associate's           360000.0
# 3                    3            Bachelor's           161000.0
# 4                    5  Bootcamp/Self-taught           283000.0
#
#    salary_min_usd  salary_max_usd         city    country   remote_work  \
# 0          155000          290000       Boston        USA       On-site
# ...

# %% [markdown]
# # Initial Dataset Inspection
#
# Before creating visualizations, the dataset is examined to understand its structure, data types, completeness, and overall quality.

# %%
# Dataset dimensions

print("Dataset Shape:", df.shape)

# Column names

print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset Shape: (1500, 25)
#
# Columns:
# ['job_id', 'job_title', 'job_category', 'experience_level', 'years_of_experience', 'education_required', 'annual_salary_usd', 'salary_min_usd', 'salary_max_usd', 'city', 'country', 'remote_work', 'company_size', 'industry', 'required_skills', 'ai_salary_premium_pct', 'demand_score', 'demand_growth_yoy_pct', 'benefits_score_10', 'posting_year', 'posting_month', 'is_senior', 'is_remote_friendly', 'is_llm_role', 'salary_tier']

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# Before creating visualizations, an exploratory analysis was performed to understand the structure of the dataset, evaluate data quality, and identify patterns related to salaries, experience levels, job demand, and AI career opportunities.
#
# The goal of this analysis is to uncover meaningful trends that will guide the development of the final visualizations and support the research question.

# %% [markdown]
# ## Data Quality Assessment
#
# The dataset was evaluated for completeness and consistency before performing analysis.
#
# The following checks were performed:
#
# - Dataset dimensions
# - Data types
# - Missing values
# - Basic descriptive statistics
# - Distribution of categorical variables

# %%
# Dataset dimensions

print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

# Missing values

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Rows: 1500
# Columns: 25
#
# Missing Values:
# job_id                   0
# job_title                0
# job_category             0
# experience_level         0
# years_of_experience      0
# education_required       0
# annual_salary_usd        0
# salary_min_usd           0
# salary_max_usd           0
# city                     0
# country                  0
# remote_work              0
# company_size             0
# industry                 0
# required_skills          0
# ai_salary_premium_pct    0
# demand_score             0
# demand_growth_yoy_pct    0
# benefits_score_10        0
# posting_year             0
# posting_month            0
# is_senior                0
# is_remote_friendly       0
# is_llm_role              0
# salary_tier              0
# dtype: int64

# %% [markdown]
# The dataset contains 1,500 AI-related job postings and 25 variables covering salary, experience, job demand, company characteristics, and location information.
#
# No missing values were identified across any of the variables, indicating that the dataset is complete and suitable for analysis without requiring additional data cleaning or imputation techniques.

# %% [markdown]
# ## Salary Overview
#
# Salary is one of the primary variables analyzed in this project.
#
# Understanding salary distribution helps identify compensation patterns across AI roles and provides context for later visualizations.

# %%
salary_summary = df['annual_salary_usd'].describe()

salary_summary
# Out:
# count      1500.000000
# mean     194892.000000
# std       66506.822013
# min       90000.000000
# 25%      144750.000000
# 50%      180000.000000
# 75%      236250.000000
# max      384000.000000
# Name: annual_salary_usd, dtype: float64

# %% [markdown]
# The average annual salary across all AI positions is approximately $195,000, with salaries ranging from $90,000 to $384,000.
#
# The wide salary range suggests substantial variation across AI career paths, indicating that factors such as specialization, experience, and market demand may play an important role in determining compensation.

# %% [markdown]
# ## Salary by Experience Level
#
# A preliminary analysis was conducted to examine how compensation changes as professionals gain experience within the AI workforce.

# %%
experience_salary = (
    df.groupby('experience_level')['annual_salary_usd']
      .mean()
      .sort_values()
)

experience_salary
# Out:
# experience_level
# Entry (0-2 yrs)     150038.961039
# Mid (3-5 yrs)       175983.783784
# Senior (6-9 yrs)    214280.219780
# Lead (10+ yrs)      240055.118110
# Name: annual_salary_usd, dtype: float64

# %% [markdown]
# Average salaries increase consistently across all experience levels. Entry-level professionals earn approximately \$150,000 annually, while lead-level professionals earn over $240,000.
#
# This progression highlights the significant financial benefits associated with career advancement in the AI industry and suggests that experience remains a key driver of compensation.

# %% [markdown]
# ## Highest-Paying AI Roles
#
# To identify the most financially rewarding career paths, average salaries were calculated for each AI job role.

# %%
top_roles = (
    df.groupby('job_title')['annual_salary_usd']
      .mean()
      .sort_values(ascending=False)
      .head(10)
)

top_roles
# Out:
# job_title
# AI Solutions Architect      251576.923077
# Senior ML Engineer          247953.125000
# LLM Engineer                240960.000000
# AI Agent Developer          225649.122807
# Multimodal AI Engineer      221791.044776
# RAG Engineer                218226.415094
# NLP Engineer                210854.545455
# Computer Vision Engineer    209173.913043
# Generative AI Engineer      206760.563380
# Deep Learning Engineer      203810.344828
# Name: annual_salary_usd, dtype: float64

# %% [markdown]
# Several emerging AI specialties appear among the highest-paying positions in the dataset. AI Solutions Architect, Senior ML Engineer, and LLM Engineer all report average salaries exceeding $240,000.
#
# Interestingly, many of the highest-paying roles are associated with advanced AI systems, generative AI, and large language models, reflecting current industry investment and demand for specialized expertise.

# %% [markdown]
# ## Demand Analysis
#
# Demand scores provide an estimate of market demand for specific AI roles.
#
# Analyzing demand alongside compensation helps identify career paths that offer both strong salaries and favorable employment opportunities.

# %%
role_summary = (
    df.groupby('job_title')
      .agg({
          'annual_salary_usd':'mean',
          'demand_score':'mean'
      })
      .reset_index()
)

role_summary.sort_values('demand_score', ascending=False)
# Out:
#                    job_title  annual_salary_usd  demand_score
# 15              LLM Engineer      240960.000000          98.0
# 16               ML Engineer      202581.818182          97.0
# 24        Senior ML Engineer      247953.125000          96.0
# 0         AI Agent Developer      225649.122807          96.0
# 3                AI Engineer      159859.375000          95.0
# 14    Generative AI Engineer      206760.563380          95.0
# 21              RAG Engineer      218226.415094          94.0
# 17            MLOps Engineer      199215.686275          93.0
# 12            Data Scientist      173639.344262          92.0
# 19              NLP Engineer      210854.545455          91.0
# 23     Senior Data Scientist      188333.333333          90.0
# 18    Multimodal AI Engineer      221791.044776          90.0
# 13    Deep Learning Engineer      203810.344828          89.0
# 7      AI Research Scientist      192280.000000          88.0
# ...

# %% [markdown]
# LLM Engineer, ML Engineer, Senior ML Engineer, and AI Agent Developer demonstrate the highest demand scores within the dataset.
#
# Many of these roles also appear among the highest-paying positions, suggesting that organizations are willing to offer premium compensation to attract talent in rapidly growing areas of artificial intelligence.

# %% [markdown]
# ## LLM Role Salary Premium
#
# Large Language Model (LLM) roles have emerged as one of the fastest-growing segments of the AI workforce.
#
# A comparison was conducted between LLM-related roles and non-LLM roles to determine whether a measurable salary premium exists.

# %%
llm_salary = (
    df.groupby('is_llm_role')['annual_salary_usd']
      .mean()
)

llm_salary
# Out:
# is_llm_role
# 0    191308.610401
# 1    207746.177370
# Name: annual_salary_usd, dtype: float64

# %% [markdown]
# LLM-related positions earn approximately \$207,746 annually on average, compared to $191,309 for non-LLM roles.
#
# This difference represents a salary premium of roughly $16,400 per year, indicating that expertise in large language models and generative AI technologies currently carries measurable economic value in the job market.

# %% [markdown]
# ## EDA Summary
#
# The exploratory analysis revealed several important patterns within the AI job market.
#
# First, compensation increases substantially as professionals gain experience, with lead-level positions earning nearly $90,000 more than entry-level roles on average.
#
# Second, specialized positions such as AI Solutions Architect, LLM Engineer, and Senior ML Engineer command some of the highest salaries in the dataset.
#
# Finally, many of the most in-demand AI roles also offer strong compensation, suggesting that organizations are actively investing in talent capable of developing and deploying advanced AI systems.
#
# These findings provide the foundation for the visualizations developed in the next section and help answer the research question regarding which AI career paths offer the strongest combination of salary and market demand.

# %% [markdown]
# # Data Visualization 1: Salary Growth Across Experience Levels

# %% [markdown]
# ## Objective
#
# The first visualization examines how compensation changes as AI professionals gain experience.
#
# Understanding salary progression helps illustrate the long-term financial opportunities available within AI careers and provides context for career planning and workforce development.

# %%
# Average salary by experience level

experience_salary = (
    df.groupby('experience_level')['annual_salary_usd']
      .mean()
      .reindex([
          'Entry (0-2 yrs)',
          'Mid (3-5 yrs)',
          'Senior (6-9 yrs)',
          'Lead (10+ yrs)'
      ])
)

experience_salary
# Out:
# experience_level
# Entry (0-2 yrs)     150038.961039
# Mid (3-5 yrs)       175983.783784
# Senior (6-9 yrs)    214280.219780
# Lead (10+ yrs)      240055.118110
# Name: annual_salary_usd, dtype: float64

# %%
from matplotlib.ticker import FuncFormatter

# Create figure
fig, ax = plt.subplots(figsize=(8, 6))

# Plot line
ax.plot(
    experience_salary.index,
    experience_salary.values,
    marker='o',
    linewidth=2.5,
    markersize=8
)

# Title
ax.set_title(
    'Average Annual Salary by Experience Level in AI Careers',
    fontsize=15,
    fontweight='bold',
    pad=15
)

# Axis Labels
ax.set_xlabel(
    'Experience Level',
    fontsize=12,
    labelpad=10
)

ax.set_ylabel(
    'Average Annual Salary ($K)',
    fontsize=12,
    labelpad=10
)

# Format Y-axis
ax.yaxis.set_major_formatter(
    FuncFormatter(lambda x, pos: f'${x/1000:.0f}K')
)

# Remove gridlines
ax.grid(False)

# Remove extra borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Dynamic headroom for labels
y_min = experience_salary.min()
y_max = experience_salary.max()
padding = (y_max - y_min) * 0.18

ax.set_ylim(
    y_min - padding * 1.15,
    y_max + padding
)

# Dynamic data labels
for x, y in zip(experience_salary.index, experience_salary.values):
    ax.annotate(
        f'${y/1000:.0f}K',
        xy=(x, y),
        xytext=(0, 12),
        textcoords='offset points',
        ha='center',
        va='bottom',
        fontsize=10,
        fontweight='bold'
    )

plt.tight_layout()

# Save for PowerPoint
plt.savefig(
    'salary_by_experience_level.png',
    dpi=300,
    bbox_inches='tight'
)

plt.savefig(
    "salary_by_experience_level.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Data Visualization 2: Highest-Paying AI Roles
#
# ## Objective
#
# This visualization identifies the highest-paying AI positions in the dataset.
#
# By comparing average salaries across job roles, the analysis highlights which AI specializations currently offer the greatest earning potential and helps professionals understand where advanced skills may provide the highest financial return.

# %%
top_roles = (
    df.groupby('job_title')['annual_salary_usd']
      .mean()
      .sort_values(ascending=False)
      .head(10)
)

top_roles
# Out:
# job_title
# AI Solutions Architect      251576.923077
# Senior ML Engineer          247953.125000
# LLM Engineer                240960.000000
# AI Agent Developer          225649.122807
# Multimodal AI Engineer      221791.044776
# RAG Engineer                218226.415094
# NLP Engineer                210854.545455
# Computer Vision Engineer    209173.913043
# Generative AI Engineer      206760.563380
# Deep Learning Engineer      203810.344828
# Name: annual_salary_usd, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(7, 6))

bars = ax.barh(
    top_roles.index,
    top_roles.values
)

# Title
ax.set_title(

    'Top 10 Highest-Paying AI Roles by Average Salary (2025–2026)',
    fontsize=15,
    fontweight='bold',
    pad=18
)

# Axis labels
ax.set_xlabel(
    'Average Annual Salary ($K)',
    fontsize=12,
    labelpad=12
)

ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')


# Remove gridlines
ax.grid(False)

# Remove extra borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.invert_yaxis()

# Format x-axis
ax.xaxis.set_major_formatter(
    FuncFormatter(lambda x, pos: f'${x/1000:.0f}K')
)

# Add labels at end of bars
for bar in bars:
    width = bar.get_width()

    ax.text(
        width + 3000,
        bar.get_y() + bar.get_height()/2,
        f'${width/1000:.0f}K',
        va='center',
        fontsize=10,
        fontweight='bold'
    )

plt.tight_layout()

plt.savefig(
    'top_10_highest_paying_ai_roles.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %% [markdown]
# ### Analysis
#
# AI Solutions Architect is the highest-paying role in the dataset, with an average annual salary of approximately \$252,000. Senior ML Engineer and LLM Engineer follow closely behind, both exceeding $240,000 annually.
#
# Many of the highest-paying positions are associated with advanced AI systems, machine learning infrastructure, and generative AI technologies. This trend suggests that organizations place a premium on professionals capable of designing, deploying, and scaling complex AI solutions.
#
# The results indicate that specialized technical expertise remains one of the strongest drivers of compensation within the AI workforce.

# %% [markdown]
# # Visualization 3: AI Career Opportunity Matrix
#
# ## Objective
#
# While previous visualizations examined salary and demand separately, this analysis combines both metrics to identify the most attractive AI career opportunities.
#
# The visualization compares average annual salary and market demand across AI roles. Reference lines representing overall average salary and demand create four quadrants that help identify positions offering the strongest combination of compensation and market demand.
#
# Roles appearing in the upper-right quadrant represent the most attractive opportunities because they combine above-average salaries with above-average demand.

# %%
# Create role-level summary
role_matrix = (
    df.groupby('job_title')
      .agg({
          'annual_salary_usd': 'mean',
          'demand_score': 'mean'
      })
      .reset_index()
)

# Reference lines
salary_avg = role_matrix['annual_salary_usd'].mean()
demand_avg = role_matrix['demand_score'].mean()

# Key roles to label
highlight_roles = [
    'LLM Engineer',
    'Senior ML Engineer',
    'AI Agent Developer',
    'RAG Engineer',
    'AI Solutions Architect',
    'ML Engineer'
]

fig, ax = plt.subplots(figsize=(8, 6))

# Scatter points
ax.scatter(
    role_matrix['demand_score'],
    role_matrix['annual_salary_usd'],
    s=80,
    alpha=0.75
)

# Average lines
ax.axvline(
    demand_avg,
    color='dimgray',
    linestyle='--',
    linewidth=1.5
)

ax.axhline(
    salary_avg,
    color='dimgray',
    linestyle='--',
    linewidth=1.5
)

# Labels
for _, row in role_matrix.iterrows():

    if row['job_title'] in highlight_roles:

        ax.annotate(
            row['job_title'],
            (row['demand_score'], row['annual_salary_usd']),
            xytext=(5, 5),
            textcoords='offset points',
            fontsize=8
        )

# Quadrant title
ax.text(
    demand_avg + 2,
    salary_avg + 40000,
    'Best Opportunities',
    fontsize=10,
    fontweight='bold'
)

# Formatting
ax.set_title(
    'AI Career Opportunity Matrix: Salary vs Market Demand',
    fontsize=15,
    fontweight='bold',
    pad=15
)

ax.set_xlabel(
    'Market Demand Score',
    fontsize=12
)

ax.set_ylabel(
    'Average Annual Salary ($K)',
    fontsize=12
)

ax.yaxis.set_major_formatter(
    FuncFormatter(lambda x, pos: f'${x/1000:.0f}K')
)

ax.grid(False)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()

plt.savefig(
    'ai_career_opportunity_matrix.png',
    dpi=300,
    bbox_inches='tight'
)

plt.show()

# %% [markdown]
# ### Analysis
#
# The upper-right quadrant represents AI careers that offer both above-average salaries and above-average demand. Roles such as LLM Engineer, Senior ML Engineer, AI Agent Developer, and RAG Engineer appear in this region, making them some of the most attractive career paths in the dataset.
#
# Several specialized AI positions earn high salaries but show more moderate demand, while other roles experience strong demand without offering equivalent compensation. This suggests that both skill specialization and market demand contribute to earning potential.
#
# Overall, the analysis highlights advanced machine learning, generative AI, and large language model roles as the strongest opportunities in today's AI job market.

# %% [markdown]
# # Visualization 4: AI Career Value Landscape
#
# ## Objective
#
# Salary alone does not provide a complete picture of career value. This visualization examines three dimensions of AI careers simultaneously: market demand, annual compensation, and AI salary premium.
#
# Bubble size represents the additional salary premium associated with AI-related skills, while position indicates overall demand and compensation. This allows us to identify roles that offer the strongest overall market value.

# %%
# ==================================================
# Create Bubble Chart Dataset
# ==================================================

bubble_df = (
    df.groupby(['job_title', 'job_category'])
      .agg({
          'annual_salary_usd': 'mean',
          'demand_score': 'mean',
          'ai_salary_premium_pct': 'mean'
      })
      .reset_index()
)

# ==================================================
# Create Opportunity Score
# ==================================================

bubble_df['opportunity_score'] = (
    bubble_df['annual_salary_usd']
    * bubble_df['demand_score']
)

# ==================================================
# Bubble Sizes
# ==================================================

bubble_df['bubble_size'] = (
    bubble_df['ai_salary_premium_pct']
    / bubble_df['ai_salary_premium_pct'].max()
) * 600 + 60

# ==================================================
# Median Values
# ==================================================

median_salary = bubble_df['annual_salary_usd'].median()
median_demand = bubble_df['demand_score'].median()

# ==================================================
# Top Roles to Label
# ==================================================

top_roles = (
    bubble_df
    .nlargest(8, 'opportunity_score')
)

# ==================================================
# Dynamic Category Colors
# ==================================================

categories = sorted(
    bubble_df['job_category'].unique()
)

colors = plt.cm.tab20(
    np.linspace(
        0,
        1,
        len(categories)
    )
)

category_color_map = dict(
    zip(categories, colors)
)

# ==================================================
# Figure Layout
# Left = Chart
# Right = Legends
# ==================================================

from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(10,7))

gs = GridSpec(
    1,
    2,
    width_ratios=[4.8,1.2],
    wspace=0.02
)

ax = fig.add_subplot(gs[0])

legend_ax = fig.add_subplot(gs[1])

legend_ax.axis("off")

# ==================================================
# Bubble Plot
# ==================================================

for category in categories:

    subset = bubble_df[
        bubble_df['job_category'] == category
    ]

    ax.scatter(
        subset['demand_score'],
        subset['annual_salary_usd'],
        s=subset['bubble_size'],
        color=category_color_map[category],
        edgecolors='black',
        linewidth=0.6,
        alpha=0.60
    )

# ==================================================
# Dynamic Labels
# ==================================================

texts = []

for _, row in top_roles.iterrows():

    texts.append(

        ax.text(
            row['demand_score'],
            row['annual_salary_usd'],
            row['job_title'],
            fontsize=8,
            fontweight='bold'
        )

    )

adjust_text(
    texts,
    ax=ax,
    arrowprops=dict(
        arrowstyle='-',
        color='gray',
        lw=0.5
    )
)

# ==================================================
# Median Lines
# ==================================================

ax.axhline(
    median_salary,
    color='gray',
    linestyle='--',
    linewidth=1.2
)

ax.axvline(
    median_demand,
    color='gray',
    linestyle='--',
    linewidth=1.2
)

# ==================================================
# Quadrant Labels
# ==================================================

box_style = dict(
    boxstyle='round,pad=0.4',
    facecolor='white',
    edgecolor='lightgray',
    alpha=0.75
)

ax.text(
    bubble_df['demand_score'].min()+1,
    bubble_df['annual_salary_usd'].max()-9000,
    'High Salary\nLow Demand',
    fontsize=8,
    fontweight='bold',
    color='darkred',
    bbox=box_style
)

ax.text(
    bubble_df['demand_score'].max()-8,
    bubble_df['annual_salary_usd'].max()-9000,
    'High Salary\nHigh Demand',
    fontsize=8,
    fontweight='bold',
    color='darkgreen',
    bbox=box_style
)

ax.text(
    bubble_df['demand_score'].min()+1,
    bubble_df['annual_salary_usd'].min()+5000,
    'Low Salary\nLow Demand',
    fontsize=8,
    fontweight='bold',
    color='darkorange',
    bbox=box_style
)

ax.text(
    bubble_df['demand_score'].max()-8,
    bubble_df['annual_salary_usd'].min()+5000,
    'Low Salary\nHigh Demand',
    fontsize=8,
    fontweight='bold',
    color='navy',
    bbox=box_style
)


# ==================================================
# Chart Title
# ==================================================

ax.set_title(
    'AI Career Value Landscape: Demand, Salary, and Premium (2025–2026)',
    fontsize=12,
    fontweight='bold',
    pad=35
)

# Subtitle

ax.text(
    0.5,
    1.03,
    'Bubble Color = Job Category • Bubble Size = Average AI Salary Premium (%)',
    transform=ax.transAxes,
    ha='center',
    fontsize=11,
    color='dimgray',
    style='italic'
)

# ==================================================
# Axis Labels
# ==================================================

ax.set_xlabel(
    'Average Market Demand Score',
    fontsize=10,
    fontweight='bold'
)

ax.set_ylabel(
    'Average Annual Salary ($K)',
    fontsize=10,
    fontweight='bold'
)

# ==================================================
# Salary Formatting
# ==================================================

ax.yaxis.set_major_formatter(
    FuncFormatter(
        lambda x, pos: f'${x/1000:.0f}K'
    )
)

# ==================================================
# Remove Grid
# ==================================================

ax.grid(False)

# Cleaner Border

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# ==================================================
# Job Category Legend
# ==================================================

from matplotlib.lines import Line2D

category_handles = []

for category in categories:

    category_handles.append(

        Line2D(
            [0],
            [0],
            marker='o',
            color='white',
            label=category,
            markerfacecolor=category_color_map[category],
            markeredgecolor='black',
            markeredgewidth=0.5,
            markersize=7
        )

    )

legend1 = legend_ax.legend(
    handles=category_handles,
    title='Job Category',
    loc='upper left',
    fontsize=8,
    title_fontsize=10,
    frameon=True,
    borderpad=0.8,
    labelspacing=0.45,
    handletextpad=0.5
)

legend_ax.add_artist(legend1)

# ==================================================
# Bubble Size Legend
# ==================================================

premium_levels = (
    np.linspace(
        bubble_df['ai_salary_premium_pct'].min(),
        bubble_df['ai_salary_premium_pct'].max(),
        4        # 4 legend bubbles
    )
    .round()
    .astype(int)
    .tolist()
)

size_handles = []

for p in premium_levels:

    bubble_area = (
        (p / bubble_df['ai_salary_premium_pct'].max())
        * 600
    ) + 60

    size_handles.append(

        Line2D(
            [0],
            [0],
            marker='o',
            color='white',
            label=f'{p}%',
            markerfacecolor='gray',
            markeredgecolor='black',
            markeredgewidth=0.5,

            # smaller than actual chart bubbles
            markersize=np.sqrt(bubble_area) * 0.35,

            alpha=0.70
        )

    )

legend2 = legend_ax.legend(
    handles=size_handles,
    title='AI Salary\nPremium',
    loc='lower left',
    fontsize=8,
    title_fontsize=10,
    frameon=True,
    borderpad=0.8,
    labelspacing=0.35,
    handletextpad=0.5
)

# ==================================================
# Remove Legend Axis
# ==================================================

legend_ax.set_xticks([])
legend_ax.set_yticks([])

for spine in legend_ax.spines.values():
    spine.set_visible(False)

# ==================================================
# Save Figure
# ==================================================

plt.savefig(
    'ai_career_value_landscape.png',
    dpi=300,
    facecolor='white'
)

plt.show()

# %% [markdown]
# ### Analysis
#
# The visualization compares AI careers across four dimensions: market demand, average annual salary, job category (bubble color), and AI salary premium (bubble size). The upper-right quadrant highlights careers that combine above-median demand with above-median salaries, making them the strongest overall opportunities. Roles such as Senior ML Engineer, LLM Engineer, AI Agent Developer, Multimodal AI Engineer, and RAG Engineer appear in this region, indicating a favorable balance between compensation and labor market demand.
#
# Bubble size further reveals the salary premium associated with AI expertise. Larger bubbles indicate roles that command higher salary premiums compared with comparable non-AI positions, emphasizing the value of specialized AI skills. Bubble colors distinguish job categories, illustrating that opportunities are distributed across multiple AI disciplines rather than being concentrated in a single field.
#
# Overall, the visualization suggests that advanced machine learning, large language models, and generative AI roles provide the strongest combination of demand, salary, and AI salary premium, making them among the most attractive career paths in the 2025–2026 AI job market.

# %% [markdown]
# ## Key Findings
#
# - Average salary increases substantially with experience level.
# - AI Solutions Architect, Senior ML Engineer, and LLM Engineer represent the highest-paying AI career paths.
# - LLM Engineer exhibits one of the strongest demand profiles.
# - AI Engineering careers dominate the high-demand, high-salary quadrant.
# - Specialized GenAI roles receive measurable salary premiums.

# %% [markdown]
# # Conclusions
#
# 1. AI Engineering careers currently offer the strongest combination of compensation and market demand.
#
# 2. Experience remains a major determinant of salary growth, with senior and lead-level professionals earning substantially more than entry-level workers.
#
# 3. Emerging roles focused on Generative AI, LLM systems, and AI agents represent promising career opportunities due to strong demand and competitive compensation.

# %% [markdown]
# # Practical Implications
# - Students can use these findings to prioritize skill development.
# - Job seekers can target roles with both strong salaries and hiring demand.
# - Employers can identify highly competitive positions requiring premium compensation.
